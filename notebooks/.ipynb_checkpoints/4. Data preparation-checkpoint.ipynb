# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem.ChemUtils import SDFToCSV
IPythonConsole.ipython_useSVG=True
from rdkit.Chem import AllChem
import csv
import pandas as pd

# %% [markdown]
# ## Read file and filter experiment

# %%
folder = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\"
generate = False
if generate == True:
    df = pd.read_csv(f"{folder}v20.data.per_cpd_well.txt", sep='\t')
    filtered_df = df[df['experiment_id'] == 419].reset_index(drop=True)
    filtered_df.to_csv(f"{folder}v20.data.per_cpd_well_419.txt", sep='\t', index=False)
else:
    filtered_df = pd.read_csv(f"{folder}v20.data.per_cpd_well_419.txt", sep='\t')

# %%
filtered_df
# Out:
#        experiment_id assay_plate_barcode  raw_value_log2  bsub_value_log2  \
# 0                419            AU053858          11.560        -0.044030
# 1                419            AU062968          11.420        -0.059780
# 2                419            AU053858          11.630         0.024330
# 3                419            AU062968          11.430        -0.053900
# 4                419            AU053858          11.600        -0.000697
# ...              ...                 ...             ...              ...
# 13574            419            AU062970          10.930        -0.346200
# 13575            419            AU062969          11.260        -0.068620
# 13576            419            AU062970          10.710        -0.558700
# 13577            419            AU062969          10.910        -0.417100
# 13578            419            AU062970           9.211        -2.061000
#
#        dmso_zscore_log2  cpd_conc_umol  master_cpd_id
# 0              -0.12760        0.00030           1788
# 1              -0.17330        0.00030           1788
# 2               0.07051        0.00061           1788
# 3              -0.15620        0.00061           1788
# 4              -0.00202        0.00120           1788
# ...                 ...            ...            ...
# 13574          -1.00300       17.00000         710154
# 13575          -0.19890       33.00000         710154
# 13576          -1.62000       33.00000         710154
# 13577          -1.20900       66.00000         710154
# 13578          -5.97300       66.00000         710154
#
# [13579 rows x 7 columns]

# %%
filtered_df['master_cpd_id'].value_counts()
# Out:
# 290356    90
# 659993    60
# 595102    32
# 616408    32
# 632104    32
#           ..
# 58472     15
# 580922    15
# 660890    14
# 411863    14
# 411724    13
# Name: master_cpd_id, Length: 448, dtype: int64

# %%
#input_file = open("C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.per_cpd_well.txt", "r")
# print(f.read())

# Geef de bestandsnamen en de sleutel op
input_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.per_cpd_well.txt"
output_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.per_cpd_well_419.txt"
key = '419'

# Schrijf de output file
def filter_rows(input_file, output_file, key):
    with open(input_file, 'r') as input_f, open(output_file, 'w') as output_f:
        first_line = input_f.readline() 
        output_f.write(first_line) 
        for line in input_f:
            if line.startswith(key):
                output_f.write(line)


# Roep de functie aan om de rijen te filteren
#filter_rows(input_file, output_file, key)

# %%
# Geef het bestandsnaam op waaruit de unieke verbindingen moeten worden gehaald
input_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.per_cpd_well_419.txt"


def get_unique_compounds(input_file):
    compounds = {}
    with open(input_file, 'r') as f:
        header = f.readline().strip()  # Lees de eerste regel (header) en verwijder de extra witruimte

        for line in f:
            line = line.strip()  # Verwijder de extra witruimte aan het begin en einde van de regel
            cols = line.split('\t')  # Splits de regel op basis van tabs ('\t')
            compound = cols[0]  # De verbinding bevindt zich op de eerste positie (index 0)

            if compound in compounds:
                compounds[compound] += 1
            else:
                compounds[compound] = 1

    return compounds


# Roep de functie aan om de unieke verbindingen en hun frequentie op te halen
unique_compounds = get_unique_compounds(input_file)

# Toon de unieke verbindingen en hun frequentie
for compound, frequency in unique_compounds.items():
    print(compound, frequency)
# Out:
# 419 13579

# %%
from collections import defaultdict
input_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.per_cpd_well_419.txt"

def get_unique_numbers(input_file):
    numbers = defaultdict(int)
    with open(input_file, 'r') as f:
        for line in f:
            line = line.strip()
            cols = line.split('\t')
            if len(cols) >= 7:
                number = cols[6]
                numbers[number] += 1

    return numbers
    #unique_numbers_list = [(number, frequency) for number, frequency in numbers.items()]
    #return unique_numbers_list

# Roep de functie aan om de unieke getallen en hun frequentie op te halen
unique_numbers = get_unique_numbers(input_file)

# Toon de unieke getallen en hun frequentie
for number, frequency in unique_numbers.items():
    print(number, frequency)
# Out:
# master_cpd_id 1
# 1788 29
# 3588 32
# 12877 32
# 17712 32
# 18311 32
# 19153 28
# 23151 32
# 23256 32
# 24173 32
# 25036 30
# 25334 32
# 25344 32
# 26874 30
# 26914 32
# 26956 30
# 26972 32
# 26979 32
# 27871 32
# 27872 30
# 27894 30
# 28172 32
# 28183 32
# 28452 32
# 28784 20
# 28801 32
# 29985 32
# 30371 32
# 30620 32
# 32372 16
# 32620 32
# 32622 32
# 32653 32
# 33166 32
# 35319 18
# 36599 32
# 37190 22
# 37479 32
# 39782 32
# 42319 32
# 44503 32
# 44511 32
# 44554 32
# 44580 28
# 45093 32
# 46792 32
# 48589 32
# 50131 32
# 50134 32
# 50163 32
# 50715 32
# 50727 32
# 50732 24
# 50737 18
# 50747 32
# 50753 28
# 52123 32
# 52133 26
# 52430 32
# 52576 32
# 52582 32
# 52882 32
# 52926 32
# 52928 32
# 53556 32
# 53705 32
# 54200 32
# 54210 32
# 55307 26
# 55512 28
# 56554 32
# 56703 32
# 58339 32
# 58455 24
# 58472 15
# 58566 32
# 60218 32
# 61097 32
# 61674 32
# 61724 32
# 62111 28
# 62602 16
# 62690 32
# 63349 32
# 63578 32
# 96171 32
# 100490 32
# 102193 32
# 119769 32
# 142931 32
# 153820 30
# 154846 32
# 176181 32
# 182395 32
# 183526 32
# 185987 32
# 215497 32
# 255961 32
# 267119 32
# 272805 32
# 277354 32
# 290356 90
# 345041 32
# 347775 32
# 347812 32
# 347813 32
# 348633 32
# 348990 32
# 348991 32
# 348992 16
# 348997 16
# 349002 32
# 349006 32
# 350548 32
# 351043 32
# 362338 32
# 362342 32
# 374747 28
# 374749 32
# 374750 32
# 374755 32
# 375219 32
# 375256 30
# 375264 32
# 375354 32
# 660230 16
# 660238 32
# 660245 32
# 660246 32
# 660247 32
# 660248 32
# 660249 32
# 660250 32
# 660251 32
# 660252 32
# 660253 32
# 660268 32
# 660269 32
# 660270 28
# 660271 32
# 660281 32
# 660283 32
# 660284 32
# 660286 32
# 660287 32
# 660288 32
# 660301 30
# 660304 32
# 660314 28
# 660317 32
# 660319 32
# 660321 32
# 660322 32
# 660325 32
# 660327 28
# 660331 28
# 660332 32
# 660341 32
# 660346 32
# 660358 30
# 660363 32
# 660391 32
# 660397 32
# 660409 32
# 660410 32
# 660411 32
# 660412 32
# 660413 32
# 660421 32
# 660424 25
# 660429 32
# 660430 32
# 660432 32
# 660433 32
# 660434 32
# 660768 32
# 660774 32
# 660777 32
# 660778 32
# 660779 32
# 660796 28
# 660798 16
# 660819 28
# 660821 32
# 660823 32
# 660840 32
# 660857 30
# 660890 14
# 660935 32
# 660985 16
# 660993 26
# 661032 32
# 661033 32
# 665818 26
# 665914 32
# 666541 32
# 666716 16
# 666910 16
# 667933 32
# 668495 16
# 668723 32
# 676728 30
# 677522 16
# 679843 32
# 679844 29
# 682993 28
# 686134 32
# 688888 30
# 705300 32
# 710154 32

# %%
# Weergeven aantal unieke compounds gebruikt
len(unique_numbers)
# Out:
# 449

# %%
# Geef de bestandsnamen en de index van de kolom op basis waarvan je wilt sorteren
input_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.per_cpd_well.txt"
output_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.per_cpd_well_419_sorted_assay.txt"
column_index = 1  # Index van de tweede kolom is 1 (nul-indexed)


def sort_rows_by_column(input_file, output_file, column_index):
    rows = []
    with open(input_file, 'r') as f:
        header = f.readline().strip()
        for line in f:
            rows.append(line.strip().split('\t'))

    sorted_rows = sorted(rows, key=lambda x: x[column_index])

    with open(output_file, 'w') as f:
        f.write(header + '\n')
        for row in sorted_rows:
            f.write('\t'.join(row) + '\n')

            
            

# Roep de functie aan om de rijen te sorteren en op te slaan in het uitvoerbestand
sort_rows_by_column(input_file, output_file, column_index)

# %%
from collections import defaultdict
input_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.curves_post_qc.txt"

def get_unique_numbers(input_file):
    numbers = defaultdict(int)
    with open(input_file, 'r') as f:
        for line in f:
            line = line.strip()
            cols = line.split('\t')
            if len(cols) >= 17:
                number = cols[16]
                numbers[number] += 1

    return numbers
    #unique_numbers_list = [(number, frequency) for number, frequency in numbers.items()]
    #return unique_numbers_list

# Roep de functie aan om de unieke getallen en hun frequentie op te halen
unique_numbers = get_unique_numbers(input_file)

# Toon de unieke getallen en hun frequentie
for number, frequency in unique_numbers.items():
    print(number, frequency)

# %%
input_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.curves_post_qc_419.txt"
output_file = "C:\\Users\\vswen\\Documents\\1. Biomedische Technologie\\BMT JAAR 5\\Kwart 4\\4. Data\\CTRPv2.0_2015_ctd2_ExpandedDataset\\v20.data.curves_post_qc_419_summary.txt"

def copy_columns(input_file, output_file, column_indices):
    with open(input_file, 'r') as f_input, open(output_file, 'w') as f_output:
        for line in f_input:
            columns = line.strip().split('\t')
            selected_columns = [columns[i] for i in column_indices]
            f_output.write('\t'.join(selected_columns) + '\n')
            
column_indices = [0, 9, 13, 15, 16]  

copy_columns(input_file, output_file, column_indices)

# %%
df_large = pd.read_csv(f"{folder}v20.data.curves_post_qc_419.txt", sep='\t')
df_summary = df_large[['experiment_id', 'p1_center', 'apparent_ec50_umol', 'area_under_curve', 'master_cpd_id']]

# %%
# df_summary = pd.read_csv(f"{folder}v20.data.curves_post_qc_419_summary.txt", sep='\t')
df_summary

# %%
df_summary.sort_values(by=['apparent_ec50_umol']).head(25)

# %%
df_smiles = pd.read_csv(f"{folder}v20.meta.per_compound.txt", sep="\t")
df_smiles.head()

# %%
df_all = pd.merge(df_summary, df_smiles, on='master_cpd_id', how='left')

# %%
df_all_sorted = df_all.sort_values(by=['apparent_ec50_umol'])

# %%
df_all_sorted.to_csv(f"{folder}v20.data.final_summary.txt", sep='\t', index=False)

# %%
import numpy as np
from tqdm.auto import tqdm
from rdkit.Chem.QED import qed
from rdkit.Chem import Descriptors, rdMolDescriptors
from sklearn import preprocessing as pre

def mol_descriptor(smiles: list[str], scale: bool = True) -> np.ndarray:

    X = []
    for smi in tqdm(smiles):
        m = Chem.MolFromSmiles(smi)
        x = np.array([Descriptors.TPSA(m),
                      Descriptors.MolLogP(m),
                      Descriptors.MolWt(m),
                      Descriptors.FpDensityMorgan2(m),
                      Descriptors.HeavyAtomMolWt(m),
                      Descriptors.MaxPartialCharge(m),
                      Descriptors.MinPartialCharge(m),
                      Descriptors.NumRadicalElectrons(m),
                      Descriptors.NumValenceElectrons(m),
                      rdMolDescriptors.CalcFractionCSP3(m),
                      rdMolDescriptors.CalcNumRings(m),
                      rdMolDescriptors.CalcNumRotatableBonds(m),
                      rdMolDescriptors.CalcNumLipinskiHBD(m),
                      rdMolDescriptors.CalcNumLipinskiHBA(m),
                      rdMolDescriptors.CalcNumHeterocycles(m),
                      rdMolDescriptors.CalcNumHeavyAtoms(m),
                      rdMolDescriptors.CalcNumAromaticRings(m),
                      rdMolDescriptors.CalcNumAtoms(m),
                      qed(m)])
        X.append(x)

    if scale:
        return pre.MinMaxScaler().fit_transform(np.array(X))
    
    return np.array(X)

 
smiles_column = df_all_sorted['cpd_smiles']

# Call the mol_descriptor function with the 'cpd_smiles' values
descriptors = mol_descriptor(smiles_column)

# Add the descriptors to your existing DataFrame
df_all_sorted[['TPSA', 'MolLogP', 'MolWt', 'FpDensityMorgan2', 'HeavyAtomMolWt',
               'MaxPartialCharge', 'MinPartialCharge', 'NumRadicalElectrons',
               'NumValenceElectrons', 'CalcFractionCSP3', 'CalcNumRings',
               'CalcNumRotatableBonds', 'CalcNumLipinskiHBD', 'CalcNumLipinskiHBA',
               'CalcNumHeterocycles', 'CalcNumHeavyAtoms', 'CalcNumAromaticRings',
               'CalcNumAtoms', 'qed']] = descriptors
df_all_sorted.to_csv(f"{folder}v20.data.final_summary.txt", sep='\t', index=False)


# Print the modified DataFrame
df_all_sorted
